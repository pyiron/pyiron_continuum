# %% [markdown]
# # Heat conduction in a two-partitioned rectangular domain

# %% [markdown]
# https://github.com/precice/tutorials/tree/master/partitioned-heat-conduction
#
# ## Summary
# We solve a simple heat equation. The domain is partitioned and the coupling is established in a Dirichlet-Neumann fashion.
#
# ## Setup
#
# We solve a partitioned heat equation. For information on the non-partitioned case, please refer to [1, p.37ff]. In this tutorial the computational domain is partitioned and coupled via preCICE. The coupling roughly follows the approach described in [2].
#
# ![Case setup of partitioned-heat-conduction case](images/tutorials-partitioned-heat-conduction-setup.png)
#
# Case setup from [3]. `D` denotes the Dirichlet participant and `N` denotes the Neumann participant.
#
# The heat equation is solved on a rectangular domain `Omega = [0,2] x [0,1]` with given Dirichlet boundary conditions. We split the domain at `x_c = 1` using a straight vertical line, the coupling interface. The left part of the domain will be referred to as the Dirichlet partition and the right part as the Neumann partition. To couple the two participants we use Dirichlet-Neumann coupling. Here, the Dirichlet participant receives Dirichlet boundary conditions (`Temperature`) at the coupling interface and solves the heat equation using these boundary conditions on the left part of the domain. Then the Dirichlet participant computes the resulting heat flux (`Flux`) from the solution and sends it to the Neumann participant. The Neumann participant uses the flux as a Neumann boundary condition to solve the heat equation on the right part of the domain. We then extract the temperature from the solution and send it back to the Dirichlet participant. This establishes the coupling between the two participants.
#
# This simple case allows us to compare the solution for the partitioned case to a known analytical solution (method of manufactures solutions, see [1, p.37ff]). For more usage examples and details, please refer to [3, sect. 4.1].

# %%
from pyiron_continuum import Project

# %%
pr = Project('partitioned_heat_conduction')
pr.remove_jobs_silently(recursive=True)
# Out:
# /tmp/ipykernel_20028/2810037951.py:2: DeprecationWarning: pyiron_base.project.generic.remove_jobs_silently is deprecated: Use pr.remove_jobs(silently=True) rather than pr.remove_jobs_silently()..
#   pr.remove_jobs_silently(recursive=True)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ## Dirichlet partition

# %%
job_d = pr.create.job.Fenics('fenics_drichlet')
# Out:
# /home/muhammad/workspace/gitRepo/pyiron-repos/pyiron_continuum/notebooks/pyiron_continuum/fenics/job/generic.py:138: UserWarning: Currently, the c++ dolfin functions used by fenics are not stored in the HDF5 file. This includes the domains, boundary condition, spatial functions. Therefore, it is not possible to reload the job properly, from HDF5 file. It would be safe to remove the Fenics jobs, after defining the project.
#   warnings.warn("Currently, the c++ dolfin functions used by fenics are not stored in the HDF5 file."

# %% [markdown]
# ### The domain and mesh

# %%
y_bottom, y_top = 0, 1
x_left, x_right = 0, 2
x_coupling = 1.0  # x coordinate of coupling interface
radius = 0.2
nx = ny = 9
job_d.domain = job_d.create.domain.regular_mesh.rectangle((x_left, y_bottom), 
                                                          (x_coupling, y_top), nx, ny, diagonal="left")

# %% [markdown]
# ### Defining the coupled and non-coupled boundaries

# %% [markdown]
# #### Non-coupled boundary
# Dirichlet boundary at the non-coupled boundaries, based on the expression `u_D`:

# %%
alpha = 3  # parameter alpha
beta = 1.3  # parameter beta
u_analytical = job_d.Expression('1 + x[0]*x[0] + alpha*x[1]*x[1] + beta*t', degree=2, alpha=alpha, beta=beta, t=0)
u_analytical_interpolated_dirichlet = job_d.interpolate_function(u_analytical)

# %%
conditions_non_coupling = 'not near(x[0], 1.0, 1E-14) \
                                    or near(x[1], 1.0, 1E-14) or near(x[1], 0., 1E-14)'   
non_coupling_bc_dirichlet = job_d.create.subdomain(conditions=conditions_non_coupling)
job_d.BCs.append(job_d.create.bc.dirichlet(expression=u_analytical,bc_fnc=non_coupling_bc_dirichlet))

# %% [markdown]
# #### Coupled boundary

# %%
conditions_coupling_bc = 'near(x[0], 1.0, 1E-14)'
coupling_bc_dirichlet = job_d.create.subdomain(conditions=conditions_coupling_bc)

# %% [markdown]
# ### PDE equation

# %%
job_d.input.dt = 0.1

# %% [markdown]
# #### Initial Condition

# %%
job_d.u_n = u_analytical_interpolated_dirichlet
job_d.u_n.rename("Temperature", "")

# %%
f = job_d.Expression('beta - 2 - 2*alpha', degree=2, alpha=alpha, beta=beta)

# %%
job_d.F = job_d.u * job_d.v * job_d.dx + job_d.dt * job_d.dot(job_d.grad_u, job_d.grad_v) * job_d.dx \
        - (job_d.u_n + job_d.dt * f) * job_d.v * job_d.dx
job_d.solution.rename("Temperature", "")

# %% [markdown]
# ### Precice Adaptor configuration

# %%
W_d = job_d.V_g.sub(0).collapse()
flux_normal = job_d.Expression("2 * x[0]", degree=1)
flux_normal_interpolated = job_d.interpolate_function(flux_normal, function_space=W_d)

# %%
job_d.adapter_conf = job_d.create.adapter_conf(config_file='precice_config/precice-adapter-config-D.json', coupling_boundary=coupling_bc_dirichlet,
                                                    write_object=flux_normal_interpolated)

# %%
def update_coupling_dirichlet(coupling_expression, coupling_boundary, job):
    job.BCs.append(job.create.bc.dirichlet(coupling_expression, coupling_boundary))

def coupling_data_dirichlet(config, job):
    job.flux.rename("Flux", "")
    job.cal_flux()
    flux_x = job.interpolate_function(job.flux.sub(0), function_space=config.write_object.function_space())
    return flux_x

# %%
job_d.adapter_conf.update_boundary_func = update_coupling_dirichlet
job_d.adapter_conf.coupling_data_func = coupling_data_dirichlet

# %% [markdown]
# ## Neumann Partition

# %%
job_n = pr.create.job.Fenics('fenics_neumann')

# %%
job_n.domain = job_n.create.domain.regular_mesh.rectangle((x_coupling, y_bottom), 
                                                          (x_right, y_top), nx, ny, diagonal="left")

# %%
non_coupling_bc_neumann = job_n.create.subdomain(conditions=conditions_non_coupling)
job_n.BCs.append(job_n.create.bc.dirichlet(expression=u_analytical,bc_fnc=non_coupling_bc_neumann))

# %%
coupling_bc_neumann = job_n.create.subdomain(conditions=conditions_coupling_bc)

# %%
u_analytical_interpolated_neumann = job_n.interpolate_function(u_analytical)

# %%
job_n.input.dt = 0.1

# %%
job_n.u_n = u_analytical_interpolated_neumann
job_n.u_n.rename("Temperature", "")

# %%
f = job_n.Expression('beta - 2 - 2*alpha', degree=2, alpha=alpha, beta=beta, t=0)
job_n.F = job_n.u * job_n.v * job_n.dx + job_n.dt * job_n.dot(job_n.grad_u, job_n.grad_v) * job_n.dx \
        - (job_n.u_n + job_n.dt * f) * job_n.v * job_n.dx
job_n.solution.rename("Temperature", "")

# %%
job_n.adapter_conf = job_n.create.adapter_conf(config_file='precice_config/precice-adapter-config-N.json', coupling_boundary=coupling_bc_neumann,
                                               write_object=u_analytical_interpolated_neumann, function_space=job_n.V_g.sub(0).collapse())

# %%
def update_coupling_neumann(coupling_expression, coupling_boundary, job):
    job.F += job.v * coupling_expression * job.ds

def coupling_data_neumann(config, job):
    return job.u

# %%
job_n.adapter_conf.update_boundary_func = update_coupling_neumann
job_n.adapter_conf.coupling_data_func = coupling_data_neumann

# %% [markdown]
# ### Creating Precice master job

# %%
job_p = pr.create.job.Precice('precice_parent')

# %% [markdown]
# **Appending fenics jobs as child job to the precice job**

# %%
job_p.child_list.append(job_d)
job_p.child_list.append(job_n)

# %% [markdown]
# **Running the precice job**

# %%
job_p.run()
# Out:
# The job precice_parent was saved and received the ID: 10
# The job fenics_drichlet was saved and received the ID: 11
# The job fenics_neumann was saved and received the ID: 12
# ---[precice]  This is preCICE version 2.3.0
# ---[precice]  Revision info: no-info [Git failed/Not a repository]
# ---[precice]  Configuration: Debug
# ---[precice]  Configuring preCICE with configuration "/home/muhammad/workspace/gitRepo/pyiron-repos/pyiron_continuum/notebooks/precice_config/precice-config.xml"
# ---[precice]  I am participant "Dirichlet"
# ---[precice]  Setting up master communication to coupling partner/s
# ---[precice]  This is preCICE version 2.3.0
# ---[precice]  Revision info: no-info [Git failed/Not a repository]
# ---[precice]  Configuration: Debug
# ---[precice]  Configuring preCICE with configuration "/home/muhammad/workspace/gitRepo/pyiron-repos/pyiron_continuum/notebooks/precice_config/precice-config.xml"
# ---[precice]  I am participant "Neumann"
# ---[precice]  Setting up master communication to coupling partner/s
# ---[precice]  Masters are connected
# ---[precice]  Masters are connected
# ---[precice]  Setting up preliminary slaves communication to coupling partner/s
# ---[precice]  Setting up preliminary slaves communication to coupling partner/s
# ---[precice]  Receive global mesh Dirichlet-Mesh
# ---[precice]  Prepare partition for mesh Dirichlet-Mesh
# ---[precice]  Gather mesh Dirichlet-Mesh
# ---[precice]  Send global mesh Dirichlet-Mesh
# ---[precice]  Receive global mesh Neumann-Mesh
# ---[precice]  Prepare partition for mesh Neumann-Mesh
# ---[precice]  Gather mesh Neumann-Mesh
# ---[precice]  Send global mesh Neumann-Mesh
# ---[precice]  Setting up slaves communication to coupling partner/s
# ---[precice]  Setting up slaves communication to coupling partner/s
# ---[precice]  Slaves are connected
# ---[precice]  Slaves are connected
# ---[precice]  iteration: 1 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, write-iteration-checkpoint
# ---[precice]  iteration: 1 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, write-initial-data write-iteration-checkpoint
# ---[precice]  Compute "read" mapping from mesh "Neumann-Mesh" to mesh "Dirichlet-Mesh".
# ---[precice]  Using tree-based preallocation for matrix C
# ---[precice]  Using tree-based preallocation for matrix A
# ---[precice]  Using rescaling. Solver converged after 5 of 10000 iterations due to sufficient relative convergence. Last residual norm: 2.70042e-13, limits: relative 3.16228e-09 (rtol 1e-09), absolute 1e-50, divergence 3.16228e+30(dtol 1e+30)
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Compute "read" mapping from mesh "Dirichlet-Mesh" to mesh "Neumann-Mesh".
# ---[precice]  Using tree-based preallocation for matrix C
# ---[precice]  Using tree-based preallocation for matrix A
# ---[precice]  Using rescaling. Solver converged after 5 of 10000 iterations due to sufficient relative convergence. Last residual norm: 2.70042e-13, limits: relative 3.16228e-09 (rtol 1e-09), absolute 1e-50, divergence 3.16228e+30(dtol 1e+30)
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.00e+00, limit = 1.00e-05, normalization = 6.32e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.02e+00, limit = 1.00e-05, normalization = 3.73e+02, conv = false
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 2 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 2 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.01e+00, limit = 1.00e-05, normalization = 1.05e+03, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.00e+00, limit = 1.00e-05, normalization = 7.08e+04, conv = false
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 3 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 3 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 5.48e+00, limit = 1.00e-05, normalization = 1.94e+02, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.00e+00, limit = 1.00e-05, normalization = 1.13e+04, conv = false
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 4 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 4 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 5.85e+00, limit = 1.00e-05, normalization = 3.36e+01, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.00e+00, limit = 1.00e-05, normalization = 2.02e+03, conv = false
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 5 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 5 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 5.19e+00, limit = 1.00e-05, normalization = 6.60e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 9.97e-01, limit = 1.00e-05, normalization = 3.60e+02, conv = false
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 6 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 6 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 2.17e+00, limit = 1.00e-05, normalization = 2.86e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 9.97e-01, limit = 1.00e-05, normalization = 8.00e+01, conv = false
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 7 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 7 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 5.50e-01, limit = 1.00e-05, normalization = 2.49e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 7.86e-01, limit = 1.00e-05, normalization = 1.87e+01, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 8 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 8 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.00e+00, limit = 1.00e-05, normalization = 3.87e+02, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.00e+00, limit = 1.00e-05, normalization = 2.24e+04, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 9 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 9 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 9.19e+00, limit = 1.00e-05, normalization = 4.20e+01, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.00e+00, limit = 1.00e-05, normalization = 2.57e+03, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 10 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 10 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.00e+01, limit = 1.00e-05, normalization = 4.18e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.00e+00, limit = 1.00e-05, normalization = 2.18e+02, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 11 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 11 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# fenics_drichlet: done with the timestep: 1
# fenics_neumann: done with the timestep: 1---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.40e+00, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 4.34e-10, limit = 1.00e-05, normalization = 9.99e+00, conv = true
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 12 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 12 of 100, time-window: 1, time: 0 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 5.60e-12, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 4.20e-10, limit = 1.00e-05, normalization = 9.99e+00, conv = true
# ---[precice]  All converged
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Time window completed
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 1 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Time window completed
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 1 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint
#
# fenics_drichlet: done with the timestep: 2
# fenics_neumann: done with the timestep: 2
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 4.94e-08, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 2.08e-02, limit = 1.00e-05, normalization = 9.83e+00, conv = false
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 2 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 2 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.01e-02, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.44e-01, limit = 1.00e-05, normalization = 1.02e+01, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 3 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 3 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 3.50e-03, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.92e-01, limit = 1.00e-05, normalization = 1.03e+01, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 4 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 4 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.35e-02, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.56e-07, limit = 1.00e-05, normalization = 9.99e+00, conv = true
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 5 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 5 of 100, time-window: 2, time: 0.1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 9.05e-09, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 7.77e-08, limit = 1.00e-05, normalization = 9.99e+00, conv = true
# ---[precice]  All converged
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Time window completed
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 1 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Time window completed
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 1 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 8.82e-06, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.25e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 2 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 2 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.72e-05, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 3.45e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 3 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 3 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.31e-05, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 2.09e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 4 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 4 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 3.82e-10, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 2.09e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 5 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 5 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 6.35e-08, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 2.09e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 6 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 6 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 5.37e-08, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 2.09e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 7 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 7 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 6.08e-08, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 2.09e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 8 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 8 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 6.44e-08, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 2.09e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 9 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 9 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 4.66e-09, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 2.09e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 10 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 10 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 3.25e-05, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 2.57e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 11 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 11 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 6.70e-06, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.61e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 12 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 12 of 100, time-window: 3, time: 0.2 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 6.05e-06, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 8.81e-05, limit = 1.00e-05, normalization = 1.00e+01, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ...
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.35e-07, limit = 1.00e-05, normalization = 9.99e+00, conv = true
# ---[precice]  All converged
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Time window completed
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 1 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Time window completed
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 1 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.40e-05, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.98e-04, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 2 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 2 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.36e-05, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 7.50e-05, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 3 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# fenics_drichlet: done with the timestep: 9
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 3 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 7.06e-06, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 9.65e-05, limit = 1.00e-05, normalization = 1.00e+01, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 4 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 4 of 100, time-window: 9, time: 0.8 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 6.94e-06, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 2.50e-06, limit = 1.00e-05, normalization = 9.99e+00, conv = true
# ---[precice]  All converged
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Time window completed
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 1 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint
# Solving linear variational problem.
# fenics_neumann: done with the timestep: 9
# fenics_neumann: done with the timestep: 10fenics_drichlet: done with the timestep: 10
#
# Solving linear variational problem.
# ---[precice]  Time window completed
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 1 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: yes, write-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 2.75e-04, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 3.94e-03, limit = 1.00e-05, normalization = 1.00e+01, conv = false
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 2 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 2 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 7.53e-04, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 6.94e-03, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 3 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 3 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 3.77e-04, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 1.54e-03, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 4 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 4 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 1.04e-04, limit = 1.00e-05, normalization = 2.45e+00, conv = false
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 4.81e-05, limit = 1.00e-05, normalization = 9.99e+00, conv = false
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice] WARNING:  Matrix Q is not sufficiently orthogonal. Failed to rorthogonalize new column after 4 iterations. New column will be discarded. The least-squares system is very bad conditioned and the quasi-Newton will most probably fail to converge.
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 5 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# Solving linear variational problem.
# ---[precice]  Mapping "Flux" consistent from "Dirichlet-Mesh" (ID 0) to "Neumann-Mesh" (ID 1) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 5 of 100, time-window: 10, time: 0.9 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: yes, time-window-complete: no, read-iteration-checkpoint
# Solving linear variational problem.
# ---[precice]  relative convergence measure: relative two-norm diff of data "Flux" = 3.35e-06, limit = 1.00e-05, normalization = 2.45e+00, conv = true
# ---[precice]  relative convergence measure: relative two-norm diff of data "Temperature" = 5.60e-08, limit = 1.00e-05, normalization = 9.99e+00, conv = true
# ---[precice]  All converged
# ---[precice] WARNING:  The number of columns in the least squares system exceeded half the number of unknowns at the interface. The system will probably become bad or ill-conditioned and the quasi-Newton acceleration may not converge. Maybe the number of allowed columns ("max-used-iterations") should be limited.
# ---[precice]  Time window completed---[precice]  Time window completed
#
# ---[precice]  iteration: 1 of 100, time-window: 11, time: 1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: no, time-window-complete: yes,
# ---[precice]  Mapping "Temperature" consistent from "Neumann-Mesh" (ID 1) to "Dirichlet-Mesh" (ID 0) for dimension 0 with polynomial set to separate
# ---[precice]  iteration: 1 of 100, time-window: 11, time: 1 of 1, time-window-size: 0.1, max-timestep-length: 0.1, ongoing: no, time-window-complete: yes,
# ---[precice]  Synchronize participants and close communication channels
# ---[precice]  Synchronize participants and close communication channels

# %%
pr.job_table()
# Out:
#    id    status chemicalformula              job            subjob  \
# 0  10  finished            None   precice_parent   /precice_parent
# 1  11  finished            None  fenics_drichlet  /fenics_drichlet
# 2  12  finished            None   fenics_neumann   /fenics_neumann
#
#        projectpath  \
# 0  /home/muhammad/
# 1  /home/muhammad/
# 2  /home/muhammad/
#
#                                                                                   project  \
# 0  workspace/gitRepo/pyiron-repos/pyiron_continuum/notebooks/partitioned_heat_conduction/
# 1  workspace/gitRepo/pyiron-repos/pyiron_continuum/notebooks/partitioned_heat_conduction/
# 2  workspace/gitRepo/pyiron-repos/pyiron_continuum/notebooks/partitioned_heat_conduction/
#
#                    timestart                   timestop  totalcputime  \
# 0 2022-01-25 01:29:54.628646                        NaT           NaN
# 1 2022-01-25 01:29:54.707416 2022-01-25 01:29:56.480669           1.0
# 2 2022-01-25 01:29:54.715938 2022-01-25 01:29:56.514049           1.0
#
#            computer hamilton hamversion parentid masterid
# 0  pyiron@cmleo14#1  Precice        0.4     None     None
# 1  pyiron@cmleo14#1   Fenics        0.4     None     None
# 2  pyiron@cmleo14#1   Fenics        0.4     None     None
